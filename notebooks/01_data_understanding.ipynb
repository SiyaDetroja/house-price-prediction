# %% [markdown]
# # House Price Prediction – Data Understanding
#
# ## Objective
# The objective of this notebook is to understand the structure, features, and basic characteristics of the house price dataset before performing any data cleaning or modeling.

# %% [markdown]
# Import Libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
file_path = '/content/drive/MyDrive/House Price India.csv'
data = pd.read_csv(file_path)
print(data.head())
# Out:
#            id   Date  No of bedrooms  No of bathrooms  living area  lot area  \
# 0  6762810635  42491               4             2.50         2920      4000
# 1  6762810998  42491               5             2.75         2910      9480
# 2  6762812605  42491               4             2.50         3310     42998
# 3  6762812919  42491               3             2.00         2710      4500
# 4  6762813105  42491               3             2.50         2600      4750
#
#    No of floors  waterfront present  No of views  house condition  ...  \
# 0           1.5                   0            0                5  ...
# 1           1.5                   0            0                3  ...
# 2           2.0                   0            0                3  ...
# 3           1.5                   0            0                4  ...
# 4           1.0                   0            0                4  ...
#
#    Built Year  Renovation Year  Postal Code  Lattitude  Longitude  \
# ...

# %%
data.shape
# Out:
# (14619, 23)

# %% [markdown]
# - The dataset contains **14619** rows and **23** columns.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14619 entries, 0 to 14618
# Data columns (total 23 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              14619 non-null  int64
#  1   Date                            14619 non-null  int64
#  2   No of bedrooms                  14619 non-null  int64
#  3   No of bathrooms                 14619 non-null  float64
#  4   living area                     14619 non-null  int64
#  5   lot area                        14619 non-null  int64
#  6   No of floors                    14619 non-null  float64
#  7   waterfront present              14619 non-null  int64
#  8   No of views                     14619 non-null  int64
#  9   house condition                 14619 non-null  int64
#  10  house grade                     14619 non-null  int64
#  11  house area(excluding basement)  14619 non-null  int64
# ...

# %% [markdown]
# - The dataset contains only numerical features.

# %%
data.describe().T
# Out:
#                                   count          mean            std  \
# id                              14619.0  6.762821e+09    6237.161975
# Date                            14619.0  4.260455e+04      67.343747
# No of bedrooms                  14619.0  3.379233e+00       0.938655
# No of bathrooms                 14619.0  2.129557e+00       0.769955
# living area                     14619.0  2.098157e+03     928.218740
# lot area                        14619.0  1.509369e+04   37920.885355
# No of floors                    14619.0  1.502326e+00       0.540241
# waterfront present              14619.0  7.661263e-03       0.087196
# No of views                     14619.0  2.328477e-01       0.765651
# house condition                 14619.0  3.430399e+00       0.664047
# house grade                     14619.0  7.682263e+00       1.174917
# house area(excluding basement)  14619.0  1.801677e+03     833.737588
# Area of the basement            14619.0  2.964802e+02     448.566731
# ...

# %% [markdown]
# - House prices show variation across the dataset.
# - Numerical features have different ranges, indicating the need for scaling later

# %%
data.columns
# Out:
# Index(['id', 'Date', 'No of bedrooms', 'No of bathrooms', 'living area',
#        'lot area', 'No of floors', 'waterfront present', 'No of views',
#        'house condition', 'house grade', 'house area(excluding basement)',
#        'Area of the basement', 'Built Year', 'Renovation Year', 'Postal Code',
#        'Lattitude', 'Longitude', 'living_area_renov', 'lot_area_renov',
#        'No of schools nearby', 'Distance from the airport', 'Price'],
#       dtype='object')

# %% [markdown]
# ## Target Variable
#
# - The target variable for this project is **Price** (house selling price).

# %%
data['No of bathrooms'].unique()
# Out:
# array([2.5 , 2.75, 2.  , 3.25, 1.75, 2.25, 1.  , 1.5 , 3.  , 8.  , 3.5 ,
#        4.25, 4.  , 5.  , 3.75, 4.5 , 5.75, 1.25, 6.5 , 4.75, 0.75, 5.25,
#        5.5 , 6.25, 6.75, 7.5 , 0.5 , 6.  , 7.75])

# %%
data['Price'].unique()
# Out:
# array([1400000, 1200000,  838000, ...,  221700,  219200,  146000])

# %% [markdown]
# ## Feature Types
#
# - All features in this dataset are numerical.
# - No categorical variables are present.
# - Therefore, encoding techniques are not required for this dataset.
